# %% [markdown]
# # Medical Rule-Based Teeth Arrangement 3.0
#
# This workflow serves as an encapsulated process of Automatic Form Generation + Automatic Arrangement.

# %%
import os
import time
import requests
import json
import trimesh
import urllib
import numpy as np

# %% [markdown]
# ## Define call rules
# Please modify the following code blocks based on the information you obtained from us.

# %%
# Chohotech service request URL, sent with the API documentation.
base_url = "<service request URL>"

# Chohotech file service URL, sent with the API documentation.
file_server_url = "<service file server URL>"

# The authentication header must be passed in. Please keep the TOKEN confidential!!! If it is leaked, please contact us immediately to reset it. All tasks using this TOKEN will be charged to your account.
zh_token = "<your company's service Token, sent with the contact>" # All API calls must be authenticated with the token.

user_group = "APIClient" # User group, usually named APIClient.

# Your company's user_id, sent with the API documentation.
user_id = "<your company's user_id>"

# If you have received creds.json, it will be read directly below.
if os.path.exists('../../creds.json'):
    creds = json.load(open('../../creds.json', 'r'))
    base_url = creds['base_url']
    file_server_url = creds['file_server_url']
    zh_token = creds['zh_token']
    user_id = creds['user_id']
    print("loaded creds from creds.json")

# %%
def upload_file(file_name):
    ext = file_name.split('.')[-1]
    data = open('../../data/' + file_name, 'rb').read()
    resp = requests.get(file_server_url + f"/scratch/{user_group}/{user_id}/upload_url?" +
                        f"postfix={ext}", # Must specify postfix, i.e., the file extension
                        headers={"X-ZH-TOKEN": zh_token}) # Get the signed upload URL
    resp.raise_for_status()

    upload_url = resp.text[1:-1] # Returns a single string JSON "string", can also use json.loads(resp.text)

    resp = requests.put(upload_url, data) # No auth header is needed for uploading to the cloud storage service

    resp.raise_for_status()
    path = "/".join(urllib.parse.urlparse(upload_url).path.lstrip("/").split("/")[3:])
    urn = f"urn:zhfile:o:s:{user_group}:{user_id}:{path}"
    return urn

def run_job_and_get_results(json_call, timeout_sec):
    headers = {
      "Content-Type": "application/json",
      "X-ZH-TOKEN": zh_token
    }

    url = base_url + '/run'

    response = requests.request("POST", url, headers=headers, data=json.dumps(json_call))
    response.raise_for_status()
    create_result = response.json()
    run_id = create_result['run_id']
    print("workflow id is", run_id)
    url = base_url + f"/run/{run_id}"

    start_time = time.time()
    while time.time()-start_time < timeout_sec:
        time.sleep(0.3)
        response = requests.request("GET", url, headers=headers)
        result = response.json()
        if result['completed'] or result['failed']:
            break

    if not result['completed']:
        if result['failed']:
            raise ValueError("API failed due to " + str(result['reason_public']))
        raise TimeoutError("API timeout")

    print("API finished in {}s".format(time.time()-start_time))
    url = base_url + f"/data/{run_id}"
    response = requests.request("GET", url, headers=headers)
    return response.json()

def retrieve_data(urn):
    return requests.get(file_server_url + f"/file/download?" + urllib.parse.urlencode({
                        "urn": urn}),
                        headers={"X-ZH-TOKEN": zh_token}).content

def retrieve_mesh(mesh_file_json):
    resp = requests.get(file_server_url + f"/file/download?" + urllib.parse.urlencode({
                        "urn": mesh_file_json['data']}),
                        headers={"X-ZH-TOKEN": zh_token})
    return trimesh.load(trimesh.util.wrap_as_stream(resp.content), file_type=mesh_file_json['type'])

# %% [markdown]
# ## oral-arrangement-medical 3.0
#
# This workflow automatically analyzes input data to generate a processing form and performs automatic teeth arrangement based on the form. Compared to Medical Rule-Based Teeth Arrangement 1.0, lateral cephalometric images and smile photos are now optional inputs.
#
# Please refer to: https://www.chohotech.com/docs/cloud-zh/#/workflow/oral-arrangement-medical-3

# %%
# Below is the pre-form. You can obtain it through the auto-form workflow, or you can customize the input similarly as shown below.
pre_form_config = {
    "remove_teeth_set": [],  # Do not specify teeth to extract; let the system decide automatically
    "gap": None,  # Automatically reserve space
    "locked_teeth_set": [],  # Do not lock any teeth
    "x_axis_position": ["U", "L"],  # Allow expansion for both upper and lower jaws
    "IPR": {
        "U": ["front", "left_back", "right_back"],  # IPR allowed in the upper jaw
        "L": ["front", "left_back", "right_back"]   # PR allowed in the lower jaw
    },
    "molar_movement": {
        "U": ["left", "right"],  # Allow bilateral molar movement in the upper jaw
        "L": ["left", "right"]   # Allow bilateral molar movement in the lower jaw
    }
}

# %%
json_call = {
  "spec_group": "mesh-processing",
  "spec_name": "oral-arrangement-medical",
  "spec_version": "3.0-snapshot",
  "user_group": user_group,
  "user_id": user_id,
  "input_data": {
      "upper_mesh": {"type":"drc", "data": upload_file("upper_jaw_scan.drc")},
      "lower_mesh": {"type":"ply", "data": upload_file("lower_jaw_scan.ply")},
      "pre_form" : json.dumps(pre_form_config)  # Optional pre-form
  },
  'output_config': {
      "teeth_comp": {"type": "ply"},        # Teeth after adjacency surface completion
      "arranged_comp": {"type": "ply"},     # Teeth arrangement result
      "upper_mesh": {"type": "ply"},        # Preprocessed upper jaw
      "lower_mesh": {"type": "ply"},        # Preprocessed lower jaw
      "u_align_matrix": {},                 # Upper jaw alignment matrix
      "l_align_matrix": {},                 # Lower jaw alignment matrix
      "transformation_dict": {},            # Transformation dictionary
      "form": {}                            # Generated treatment plan
  }
}
result_arrangement = run_job_and_get_results(json_call, 1200)

# %%
print(f"Keys included in the output: {list(result_arrangement.keys())}")

# %%
# Teeth Arrangement Result
sum([retrieve_mesh(result_arrangement['arranged_comp'][k]) for k in result_arrangement['arranged_comp'].keys()], None).show()
